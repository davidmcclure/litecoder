# %%
import re

from tqdm import tqdm
from collections import defaultdict, Counter, UserDict
from itertools import product
from cached_property import cached_property

from litecoder.db import session, City, CityAltName

# %%
def keyify(text):
    
    text = text.lower()
    text = text.strip()

    text = text.replace('.', '')
    text = re.sub('[,-]', ' ', text)
    
    # 2+ whitespace -> 1 space
    text = re.sub('\s{2,}', ' ', text)
    
    return text

# %%
keyify('la-la land')
# Out:
# 'la la land'

# %%
keyify('Tuscaloosa, AL')
# Out:
# 'tuscaloosa al'

# %%
USA_NAMES = (
    'USA',
    'United States',
    'United States of America',
    'US',
    'America',
)

class USCityKeyGen:
    
    # TODO: Separate class?
    @cached_property
    def int_name_counts(self):
        names = [keyify(r[0]) for r in session.query(City.name)]
        return Counter(names)
    
    def raw_keys_iter(self, city):
        """Enumerate index keys for a city.
        
        Args:
            city (db.City)
            
        Yields: str
        """
        # TODO: Alt names
        names = (city.name, *city.alt_name_strings)
        
        # TODO: Parametrize
        is_big = city.population and city.population > 500000
        
        name_is_unique = self.int_name_counts[keyify(city.name)] == 1
        
        # If unique or high population.
        if is_big or name_is_unique:

            # Bare name
            for name in names:
                yield name

            # Bare name + USA
            for name, usa in product(names, USA_NAMES):
                yield ' '.join((name, usa))
            
        states = (city.name_a1, city.us_state_abbr)
        
        # Name + state
        for name, state in product(names, states):
            yield ' '.join((name, state))

        # Name + state + USA
        for name, state, usa in product(names, states, USA_NAMES):
            yield ' '.join((name, state, usa))
            
    def __call__(self, city):
        for text in self.raw_keys_iter(city):
            yield keyify(text)

# %%
city_key_iter = USCityKeyGen()

# %%
la = City.query.filter(City.country_iso=='US').filter(City.name=='Los Angeles').first()
tuscaloosa = City.query.filter(City.country_iso=='US').filter(City.name=='Tuscaloosa').first()

# %%
list(city_key_iter(la))
# Out:
# ['los angeles',
#  'the plains of id',
#  'tehrangeles',
#  'shangri la',
#  'lotus land',
#  'la',
#  'lotus',
#  'la la land',
#  'lax',
#  'southland',
#  'el lay',
#  'southern california',
#  'smell a',
#  'city of angels',
#  'tinseltown',
#  'hell a',
#  'lost angels',
#  'the big orange',
#  'sc',
#  'la',
#  'lost angeles',
#  'los angeles usa',
#  'los angeles united states',
#  'los angeles united states of america',
#  'los angeles us',
#  'los angeles america',
#  'the plains of id usa',
#  'the plains of id united states',
#  'the plains of id united states of america',
#  'the plains of id us',
#  'the plains of id america',
#  'tehrangeles usa',
#  'tehrangeles united states',
#  'tehrangeles united states of america',
#  'tehrangeles us',
#  'tehrangeles america',
#  'shangri la usa',
#  'shangri la united states',
#  'shangri la united states of america',
#  'shangri la us',
#  'shangri la america',
#  'lotus land usa',
#  'lotus land united states',
#  'lotus land united states of america',
#  'lotus land us',
#  'lotus land america',
#  'la usa',
#  'la united states',
#  'la united states of america',
#  'la us',
#  'la america',
#  'lotus usa',
#  'lotus united states',
#  'lotus united states of america',
#  'lotus us',
#  'lotus america',
#  'la la land usa',
#  'la la land united states',
#  'la la land united states of america',
#  'la la land us',
#  'la la land america',
#  'lax usa',
#  'lax united states',
#  'lax united states of america',
#  'lax us',
#  'lax america',
#  'southland usa',
#  'southland united states',
#  'southland united states of america',
#  'southland us',
#  'southland america',
#  'el lay usa',
#  'el lay united states',
#  'el lay united states of america',
#  'el lay us',
#  'el lay america',
#  'southern california usa',
#  'southern california united states',
#  'southern california united states of america',
#  'southern california us',
#  'southern california america',
#  'smell a usa',
#  'smell a united states',
#  'smell a united states of america',
#  'smell a us',
#  'smell a america',
#  'city of angels usa',
#  'city of angels united states',
#  'city of angels united states of america',
#  'city of angels us',
#  'city of angels america',
#  'tinseltown usa',
#  'tinseltown united states',
#  'tinseltown united states of america',
#  'tinseltown us',
#  'tinseltown america',
#  'hell a usa',
#  'hell a united states',
#  'hell a united states of america',
#  'hell a us',
#  'hell a america',
#  'lost angels usa',
#  'lost angels united states',
#  'lost angels united states of america',
#  'lost angels us',
#  'lost angels america',
#  'the big orange usa',
#  'the big orange united states',
#  'the big orange united states of america',
#  'the big orange us',
#  'the big orange america',
#  'sc usa',
#  'sc united states',
#  'sc united states of america',
#  'sc us',
#  'sc america',
#  'la usa',
#  'la united states',
#  'la united states of america',
#  'la us',
#  'la america',
#  'lost angeles usa',
#  'lost angeles united states',
#  'lost angeles united states of america',
#  'lost angeles us',
#  'lost angeles america',
#  'los angeles california',
#  'los angeles ca',
#  'the plains of id california',
#  'the plains of id ca',
#  'tehrangeles california',
#  'tehrangeles ca',
#  'shangri la california',
#  'shangri la ca',
#  'lotus land california',
#  'lotus land ca',
#  'la california',
#  'la ca',
#  'lotus california',
#  'lotus ca',
#  'la la land california',
#  'la la land ca',
#  'lax california',
#  'lax ca',
#  'southland california',
#  'southland ca',
#  'el lay california',
#  'el lay ca',
#  'southern california california',
#  'southern california ca',
#  'smell a california',
#  'smell a ca',
#  'city of angels california',
#  'city of angels ca',
#  'tinseltown california',
#  'tinseltown ca',
#  'hell a california',
#  'hell a ca',
#  'lost angels california',
#  'lost angels ca',
#  'the big orange california',
#  'the big orange ca',
#  'sc california',
#  'sc ca',
#  'la california',
#  'la ca',
#  'lost angeles california',
#  'lost angeles ca',
#  'los angeles california usa',
#  'los angeles california united states',
#  'los angeles california united states of america',
#  'los angeles california us',
#  'los angeles california america',
#  'los angeles ca usa',
#  'los angeles ca united states',
#  'los angeles ca united states of america',
#  'los angeles ca us',
#  'los angeles ca america',
#  'the plains of id california usa',
#  'the plains of id california united states',
#  'the plains of id california united states of america',
#  'the plains of id california us',
#  'the plains of id california america',
#  'the plains of id ca usa',
#  'the plains of id ca united states',
#  'the plains of id ca united states of america',
#  'the plains of id ca us',
#  'the plains of id ca america',
#  'tehrangeles california usa',
#  'tehrangeles california united states',
#  'tehrangeles california united states of america',
#  'tehrangeles california us',
#  'tehrangeles california america',
#  'tehrangeles ca usa',
#  'tehrangeles ca united states',
#  'tehrangeles ca united states of america',
#  'tehrangeles ca us',
#  'tehrangeles ca america',
#  'shangri la california usa',
#  'shangri la california united states',
#  'shangri la california united states of america',
#  'shangri la california us',
#  'shangri la california america',
#  'shangri la ca usa',
#  'shangri la ca united states',
#  'shangri la ca united states of america',
#  'shangri la ca us',
#  'shangri la ca america',
#  'lotus land california usa',
#  'lotus land california united states',
#  'lotus land california united states of america',
#  'lotus land california us',
#  'lotus land california america',
#  'lotus land ca usa',
#  'lotus land ca united states',
#  'lotus land ca united states of america',
#  'lotus land ca us',
#  'lotus land ca america',
#  'la california usa',
#  'la california united states',
#  'la california united states of america',
#  'la california us',
#  'la california america',
#  'la ca usa',
#  'la ca united states',
#  'la ca united states of america',
#  'la ca us',
#  'la ca america',
#  'lotus california usa',
#  'lotus california united states',
#  'lotus california united states of america',
#  'lotus california us',
#  'lotus california america',
#  'lotus ca usa',
#  'lotus ca united states',
#  'lotus ca united states of america',
#  'lotus ca us',
#  'lotus ca america',
#  'la la land california usa',
#  'la la land california united states',
#  'la la land california united states of america',
#  'la la land california us',
#  'la la land california america',
#  'la la land ca usa',
#  'la la land ca united states',
#  'la la land ca united states of america',
#  'la la land ca us',
#  'la la land ca america',
#  'lax california usa',
#  'lax california united states',
#  'lax california united states of america',
#  'lax california us',
#  'lax california america',
#  'lax ca usa',
#  'lax ca united states',
#  'lax ca united states of america',
#  'lax ca us',
#  'lax ca america',
#  'southland california usa',
#  'southland california united states',
#  'southland california united states of america',
#  'southland california us',
#  'southland california america',
#  'southland ca usa',
#  'southland ca united states',
#  'southland ca united states of america',
#  'southland ca us',
#  'southland ca america',
#  'el lay california usa',
#  'el lay california united states',
#  'el lay california united states of america',
#  'el lay california us',
#  'el lay california america',
#  'el lay ca usa',
#  'el lay ca united states',
#  'el lay ca united states of america',
#  'el lay ca us',
#  'el lay ca america',
#  'southern california california usa',
#  'southern california california united states',
#  'southern california california united states of america',
#  'southern california california us',
#  'southern california california america',
#  'southern california ca usa',
#  'southern california ca united states',
#  'southern california ca united states of america',
#  'southern california ca us',
#  'southern california ca america',
#  'smell a california usa',
#  'smell a california united states',
#  'smell a california united states of america',
#  'smell a california us',
#  'smell a california america',
#  'smell a ca usa',
#  'smell a ca united states',
#  'smell a ca united states of america',
#  'smell a ca us',
#  'smell a ca america',
#  'city of angels california usa',
#  'city of angels california united states',
#  'city of angels california united states of america',
#  'city of angels california us',
#  'city of angels california america',
#  'city of angels ca usa',
#  'city of angels ca united states',
#  'city of angels ca united states of america',
#  'city of angels ca us',
#  'city of angels ca america',
#  'tinseltown california usa',
#  'tinseltown california united states',
#  'tinseltown california united states of america',
#  'tinseltown california us',
#  'tinseltown california america',
#  'tinseltown ca usa',
#  'tinseltown ca united states',
#  'tinseltown ca united states of america',
#  'tinseltown ca us',
#  'tinseltown ca america',
#  'hell a california usa',
#  'hell a california united states',
#  'hell a california united states of america',
#  'hell a california us',
#  'hell a california america',
#  'hell a ca usa',
#  'hell a ca united states',
#  'hell a ca united states of america',
#  'hell a ca us',
#  'hell a ca america',
#  'lost angels california usa',
#  'lost angels california united states',
#  'lost angels california united states of america',
#  'lost angels california us',
#  'lost angels california america',
#  'lost angels ca usa',
#  'lost angels ca united states',
#  'lost angels ca united states of america',
#  'lost angels ca us',
#  'lost angels ca america',
#  'the big orange california usa',
#  'the big orange california united states',
#  'the big orange california united states of america',
#  'the big orange california us',
#  'the big orange california america',
#  'the big orange ca usa',
#  'the big orange ca united states',
#  'the big orange ca united states of america',
#  'the big orange ca us',
#  'the big orange ca america',
#  'sc california usa',
#  'sc california united states',
#  'sc california united states of america',
#  'sc california us',
#  'sc california america',
#  'sc ca usa',
#  'sc ca united states',
#  'sc ca united states of america',
#  'sc ca us',
#  'sc ca america',
#  'la california usa',
#  'la california united states',
#  'la california united states of america',
#  'la california us',
#  'la california america',
#  'la ca usa',
#  'la ca united states',
#  'la ca united states of america',
#  'la ca us',
#  'la ca america',
#  'lost angeles california usa',
#  'lost angeles california united states',
#  'lost angeles california united states of america',
#  'lost angeles california us',
#  'lost angeles california america',
#  'lost angeles ca usa',
#  'lost angeles ca united states',
#  'lost angeles ca united states of america',
#  'lost angeles ca us',
#  'lost angeles ca america']

# %%
list(city_key_iter(tuscaloosa))
# Out:
# ['tuscaloosa',
#  'tcl',
#  'tus',
#  'tuscaloosa usa',
#  'tuscaloosa united states',
#  'tuscaloosa united states of america',
#  'tuscaloosa us',
#  'tuscaloosa america',
#  'tcl usa',
#  'tcl united states',
#  'tcl united states of america',
#  'tcl us',
#  'tcl america',
#  'tus usa',
#  'tus united states',
#  'tus united states of america',
#  'tus us',
#  'tus america',
#  'tuscaloosa alabama',
#  'tuscaloosa al',
#  'tcl alabama',
#  'tcl al',
#  'tus alabama',
#  'tus al',
#  'tuscaloosa alabama usa',
#  'tuscaloosa alabama united states',
#  'tuscaloosa alabama united states of america',
#  'tuscaloosa alabama us',
#  'tuscaloosa alabama america',
#  'tuscaloosa al usa',
#  'tuscaloosa al united states',
#  'tuscaloosa al united states of america',
#  'tuscaloosa al us',
#  'tuscaloosa al america',
#  'tcl alabama usa',
#  'tcl alabama united states',
#  'tcl alabama united states of america',
#  'tcl alabama us',
#  'tcl alabama america',
#  'tcl al usa',
#  'tcl al united states',
#  'tcl al united states of america',
#  'tcl al us',
#  'tcl al america',
#  'tus alabama usa',
#  'tus alabama united states',
#  'tus alabama united states of america',
#  'tus alabama us',
#  'tus alabama america',
#  'tus al usa',
#  'tus al united states',
#  'tus al united states of america',
#  'tus al us',
#  'tus al america']

# %%
class CityIndex(KeyIndex):
    
    def __init__(self):
        self._idx = defaultdict(set)
        
    def __getitem__(self, text):
        return self._idx[keyify(text)]
    
    def build(self):
        """Index all US cities.
        """
        iter_keys = USCityKeyGen()
        
        cities = City.query.filter(City.country_iso=='US')
        
        for city in tqdm(cities):
            
            try:
                
                # Generate keys, ensure no errors.
                keys = list(iter_keys(city))
                
                # Index complete key set.
                for key in iter_keys(city):
                    self[key].add(city.wof_id)

            except Exception as e:
                pass

# %%
ci = CityIndex()
ci.build()
# Out:
# 54727it [01:59, 457.72it/s]

# %%
len(ci._idx)
# Out:
# 965166

# %%
ci['nyc']
# Out:
# {85977539}
