# %%
import pandas as pd

from litecoder.usa import USCityIndex, USStateIndex

# %%
city_idx = USCityIndex.load()

# %%
state_idx = USStateIndex.load()

# %%
city_idx
# Out:
# USCityIndex<637590 keys, 54727 entities>

# %%
state_idx
# Out:
# USStateIndex<561 keys, 51 entities>

# %%
locs = pd.read_json('/Users/dclure/Projects/geovec-data/data/locations-90k.json', lines=True)

# %%
for r in locs.dropna().itertuples():
    
    res = []
    
    res += city_idx[r.location]
    res += state_idx[r.location]
    
    if res:
        print('%s ~ %s' % (r.location.strip(), res))
# Out:
# Los Angeles, CA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# California, USA ~ [StateMatch<California, United States, wof:85688637>]
# New York, USA ~ [CityMatch<New York, New York, United States, wof:85977539>, StateMatch<New York, United States, wof:85688543>]
# New York, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Chicago, IL ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# Houston, TX ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Texas, USA ~ [StateMatch<Texas, United States, wof:85688753>]
# Florida, USA ~ [StateMatch<Florida, United States, wof:85688651>]
# Atlanta, GA ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Washington, DC ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>]
# San Francisco, CA ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# New York ~ [CityMatch<New York, New York, United States, wof:85977539>, StateMatch<New York, United States, wof:85688543>]
# Miami, FL ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Seattle, WA ~ [CityMatch<Seattle, Washington, United States, wof:101730401>]
# Brooklyn, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Dallas, TX ~ [CityMatch<Dallas, Texas, United States, wof:101724385>]
# Las Vegas, NV ~ [CityMatch<Las Vegas, Nevada, United States, wof:85974801>]
# Boston, MA ~ [CityMatch<Boston, Massachusetts, United States, wof:85950361>]
# New Jersey, USA ~ [StateMatch<New Jersey, United States, wof:85688607>]
# Virginia, USA ~ [StateMatch<Virginia, United States, wof:85688747>]
# Philadelphia, PA ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Los Angeles ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# San Diego, CA ~ [CityMatch<San Diego, California, United States, wof:85922227>]
# Austin, TX ~ [CityMatch<Austin, Texas, United States, wof:101724577>]
# California ~ [StateMatch<California, United States, wof:85688637>]
# Texas ~ [StateMatch<Texas, United States, wof:85688753>]
# NYC ~ [CityMatch<New York, New York, United States, wof:85977539>]
# North Carolina, USA ~ [StateMatch<North Carolina, United States, wof:85688773>]
# Ohio, USA ~ [StateMatch<Ohio, United States, wof:85688485>]
# Chicago ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# Pennsylvania, USA ~ [StateMatch<Pennsylvania, United States, wof:85688481>]
# Michigan, USA ~ [StateMatch<Michigan, United States, wof:85688599>]
# San Antonio, TX ~ [CityMatch<San Antonio, Texas, United States, wof:101724653>]
# Georgia, USA ~ [StateMatch<Georgia, United States, wof:85688535>]
# Orlando, FL ~ [CityMatch<Orlando, Florida, United States, wof:85933091>]
# Florida ~ [StateMatch<Florida, United States, wof:85688651>]
# Denver, CO ~ [CityMatch<Denver, Colorado, United States, wof:85928879>]
# New Orleans, LA ~ [CityMatch<New Orleans, Louisiana, United States, wof:85948111>]
# Portland, OR ~ [CityMatch<Portland, Oregon, United States, wof:101715829>]
# Phoenix, AZ ~ [CityMatch<Phoenix, Arizona, United States, wof:85917479>]
# New York City ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Charlotte, NC ~ [CityMatch<Charlotte, North Carolina, United States, wof:85981333>]
# Pittsburgh, PA ~ [CityMatch<Pittsburgh, Pennsylvania, United States, wof:101718805>]
# Baltimore, MD ~ [CityMatch<Baltimore, Maryland, United States, wof:85949461>]
# Nashville, TN ~ [CityMatch<Nashville, Tennessee, United States, wof:1141909337>, CityMatch<Nashville, Tennessee, United States, wof:101723183>]
# Detroit, MI ~ [CityMatch<Detroit, Michigan, United States, wof:85951091>]
# Maryland, USA ~ [StateMatch<Maryland, United States, wof:85688501>]
# Columbus, OH ~ [CityMatch<Columbus, Ohio, United States, wof:101712381>]
# Illinois, USA ~ [StateMatch<Illinois, United States, wof:85688697>]
# Massachusetts, USA ~ [StateMatch<Massachusetts, United States, wof:85688645>]
# Cleveland, OH ~ [CityMatch<Cleveland, Ohio, United States, wof:101712563>]
# Arizona, USA ~ [StateMatch<Arizona, United States, wof:85688719>]
# Manhattan, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# New Jersey ~ [StateMatch<New Jersey, United States, wof:85688607>]
# Tampa, FL ~ [CityMatch<Tampa, Florida, United States, wof:85931789>]
# Indianapolis, IN ~ [CityMatch<Indianapolis, Indiana, United States, wof:85942569>]
# Minneapolis, MN ~ [CityMatch<Minneapolis, Minnesota, United States, wof:85969169>]
# Washington, USA ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>, StateMatch<Washington, United States, wof:85688623>]
# San Francisco ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Indiana, USA ~ [StateMatch<Indiana, United States, wof:85688709>]
# Colorado, USA ~ [StateMatch<Colorado, United States, wof:85688603>]
# Washington ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>, StateMatch<Washington, United States, wof:85688623>]
# Ohio ~ [StateMatch<Ohio, United States, wof:85688485>]
# Wisconsin, USA ~ [StateMatch<Wisconsin, United States, wof:85688517>]
# Michigan ~ [StateMatch<Michigan, United States, wof:85688599>]
# Tennessee, USA ~ [StateMatch<Tennessee, United States, wof:85688701>]
# South Carolina, USA ~ [StateMatch<South Carolina, United States, wof:85688683>]
# Raleigh, NC ~ [CityMatch<Raleigh, North Carolina, United States, wof:85980569>]
# Atlanta ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Missouri, USA ~ [StateMatch<Missouri, United States, wof:85688661>]
# NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Kansas City, MO ~ [CityMatch<Kansas City, Missouri, United States, wof:1141909161>, CityMatch<Kansas City, Missouri, United States, wof:85970739>]
# Louisiana, USA ~ [StateMatch<Louisiana, United States, wof:85688735>]
# Minnesota, USA ~ [StateMatch<Minnesota, United States, wof:85688727>]
# Buffalo, NY ~ [CityMatch<Buffalo, New York, United States, wof:85978023>]
# Sacramento, CA ~ [CityMatch<Sacramento, California, United States, wof:85922845>]
# Cincinnati, OH ~ [CityMatch<Cincinnati, Ohio, United States, wof:101712203>]
# Connecticut, USA ~ [StateMatch<Connecticut, United States, wof:85688629>]
# Oklahoma, USA ~ [StateMatch<Oklahoma, United States, wof:85688585>]
# Oakland, CA ~ [CityMatch<Oakland, California, United States, wof:85921881>]
# Seattle ~ [CityMatch<Seattle, Washington, United States, wof:101730401>]
# Oregon, USA ~ [StateMatch<Oregon, United States, wof:85688513>]
# Fort Worth, TX ~ [CityMatch<Fort Worth, Texas, United States, wof:101724443>]
# Louisville, KY ~ [CityMatch<Louisville, Kentucky, United States, wof:1141908697>, CityMatch<Louisville, Kentucky, United States, wof:85947523>]
# San Jose, CA ~ [CityMatch<San Jose, California, United States, wof:85922347>]
# Kentucky, USA ~ [StateMatch<Kentucky, United States, wof:85688641>]
# Memphis, TN ~ [CityMatch<Memphis, Tennessee, United States, wof:101722645>]
# Alabama, USA ~ [StateMatch<Alabama, United States, wof:85688675>]
# Boston ~ [CityMatch<Boston, Massachusetts, United States, wof:85950361>]
# Bronx, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# North Carolina ~ [StateMatch<North Carolina, United States, wof:85688773>]
# Queens, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Milwaukee, WI ~ [CityMatch<Milwaukee, Wisconsin, United States, wof:101732987>]
# LA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Maryland ~ [StateMatch<Maryland, United States, wof:85688501>]
# Richmond, VA ~ [CityMatch<Richmond, Virginia, United States, wof:101728675>]
# St Louis, MO ~ [CityMatch<St. Louis, Missouri, United States, wof:85971343>]
# Georgia ~ [StateMatch<Georgia, United States, wof:85688535>]
# Houston ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Philadelphia ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Las Vegas ~ [CityMatch<Las Vegas, Nevada, United States, wof:85974801>]
# Colorado ~ [StateMatch<Colorado, United States, wof:85688603>]
# San Diego ~ [CityMatch<San Diego, California, United States, wof:85922227>]
# Long Beach, CA ~ [CityMatch<Long Beach, California, United States, wof:85923525>]
# Tucson, AZ ~ [CityMatch<Tucson, Arizona, United States, wof:85917235>]
# Mississippi, USA ~ [StateMatch<Mississippi, United States, wof:85688579>]
# Arizona ~ [StateMatch<Arizona, United States, wof:85688719>]
# Miami ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Nebraska, USA ~ [StateMatch<Nebraska, United States, wof:85688563>]
# Virginia ~ [StateMatch<Virginia, United States, wof:85688747>]
# Nueva York, USA ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Washington, D.C. ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>]
# Birmingham, AL ~ [CityMatch<Birmingham, Alabama, United States, wof:85914465>]
# Omaha, NE ~ [CityMatch<Omaha, Nebraska, United States, wof:85973483>]
# Illinois ~ [StateMatch<Illinois, United States, wof:85688697>]
# Oklahoma City, OK ~ [CityMatch<Oklahoma City, Oklahoma, United States, wof:101714461>]
# Albuquerque, NM ~ [CityMatch<Albuquerque, New Mexico, United States, wof:85976715>]
# Knoxville, TN ~ [CityMatch<Knoxville, Tennessee, United States, wof:101722865>]
# Indiana ~ [StateMatch<Indiana, United States, wof:85688709>]
# Kansas, USA ~ [StateMatch<Kansas, United States, wof:85688555>]
# Minnesota ~ [StateMatch<Minnesota, United States, wof:85688727>]
# El Paso, TX ~ [CityMatch<El Paso, Texas, United States, wof:101724863>]
# Salt Lake City, UT ~ [CityMatch<Salt Lake City, Utah, United States, wof:101728075>]
# Baton Rouge, LA ~ [CityMatch<Baton Rouge, Louisiana, United States, wof:85948205>]
# Miami Beach, FL ~ [CityMatch<Miami Beach, Florida, United States, wof:85933671>]
# Beverly Hills, CA ~ [CityMatch<Beverly Hills, California, United States, wof:85923701>]
# Wisconsin ~ [StateMatch<Wisconsin, United States, wof:85688517>]
# Pennsylvania ~ [StateMatch<Pennsylvania, United States, wof:85688481>]
# Massachusetts ~ [StateMatch<Massachusetts, United States, wof:85688645>]
# Washington DC ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>]
# Iowa, USA ~ [StateMatch<Iowa, United States, wof:85688713>]
# Brooklyn ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Houston, Texas ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Tallahassee, FL ~ [CityMatch<Tallahassee, Florida, United States, wof:85933373>]
# Utah ~ [StateMatch<Utah, United States, wof:85688567>]
# Honolulu, HI ~ [CityMatch<Honolulu, Hawaii, United States, wof:1141909415>]
# Fresno, CA ~ [CityMatch<Fresno, California, United States, wof:85922995>]
# Arkansas, USA ~ [StateMatch<Arkansas, United States, wof:85688549>]
# Bay Area ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Charleston, SC ~ [CityMatch<Charleston, South Carolina, United States, wof:101720747>]
# Dayton, OH ~ [CityMatch<Dayton, Ohio, United States, wof:101712161>]
# Colorado Springs, CO ~ [CityMatch<Colorado Springs, Colorado, United States, wof:85929457>]
# West Virginia, USA ~ [StateMatch<West Virginia, United States, wof:85688589>]
# New Orleans ~ [CityMatch<New Orleans, Louisiana, United States, wof:85948111>]
# Gotham City ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Los Angeles, California ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Austin, Texas ~ [CityMatch<Austin, Texas, United States, wof:101724577>]
# Utah, USA ~ [StateMatch<Utah, United States, wof:85688567>]
# Oregon ~ [StateMatch<Oregon, United States, wof:85688513>]
# Dallas, Texas ~ [CityMatch<Dallas, Texas, United States, wof:101724385>]
# Dallas ~ [CityMatch<Dallas, Texas, United States, wof:101724385>]
# Grand Rapids, MI ~ [CityMatch<Grand Rapids, Michigan, United States, wof:85951337>]
# Pittsburgh ~ [CityMatch<Pittsburgh, Pennsylvania, United States, wof:101718805>]
# Virginia Beach, VA ~ [CityMatch<Virginia Beach, Virginia, United States, wof:101728745>, CityMatch<Virginia Beach, Virginia, United States, wof:1125983951>]
# chicago ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# Hawaii, USA ~ [StateMatch<Hawaii, United States, wof:85688671>]
# Baltimore ~ [CityMatch<Baltimore, Maryland, United States, wof:85949461>]
# San Mateo, CA ~ [CityMatch<San Mateo, California, United States, wof:85922431>]
# Greensboro, NC ~ [CityMatch<Greensboro, North Carolina, United States, wof:85980391>]
# Fort Lauderdale, FL ~ [CityMatch<Fort Lauderdale, Florida, United States, wof:85932397>]
# Tulsa, OK ~ [CityMatch<Tulsa, Oklahoma, United States, wof:101714287>]
# Rochester, NY ~ [CityMatch<Rochester, New York, United States, wof:85977591>]
# Arlington, TX ~ [CityMatch<Arlington, Texas, United States, wof:101723641>, CityMatch<Arlington, Texas, United States, wof:1141906273>]
# Chattanooga, TN ~ [CityMatch<Chattanooga, Tennessee, United States, wof:101723043>]
# Jacksonville, FL ~ [CityMatch<Jacksonville, Florida, United States, wof:85932547>]
# Delaware, USA ~ [StateMatch<Delaware, United States, wof:85688611>]
# Indianapolis ~ [CityMatch<Indianapolis, Indiana, United States, wof:85942569>]
# Kentucky ~ [StateMatch<Kentucky, United States, wof:85688641>]
# Scottsdale, AZ ~ [CityMatch<Scottsdale, Arizona, United States, wof:85917475>, CityMatch<Scottsdale, Arizona, United States, wof:1141906829>]
# Tennessee ~ [StateMatch<Tennessee, United States, wof:85688701>]
# nyc ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Maine, USA ~ [StateMatch<Maine, United States, wof:85688769>]
# Durham, NC ~ [CityMatch<Durham, North Carolina, United States, wof:85980565>]
# Riverside, CA ~ [CityMatch<Riverside, California, United States, wof:85923345>]
# Wichita, KS ~ [CityMatch<Wichita, Kansas, United States, wof:85945871>]
# Connecticut ~ [StateMatch<Connecticut, United States, wof:85688629>]
# Bay Area, CA ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# california ~ [StateMatch<California, United States, wof:85688637>]
# Portland, Oregon ~ [CityMatch<Portland, Oregon, United States, wof:101715829>]
# ATL ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Nevada, USA ~ [StateMatch<Nevada, United States, wof:85688531>]
# New York, New York ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Louisiana ~ [StateMatch<Louisiana, United States, wof:85688735>]
# South Carolina ~ [StateMatch<South Carolina, United States, wof:85688683>]
# Alabama ~ [StateMatch<Alabama, United States, wof:85688675>]
# Corpus Christi, TX ~ [CityMatch<Corpus Christi, Texas, United States, wof:101724325>]
# new york ~ [CityMatch<New York, New York, United States, wof:85977539>, StateMatch<New York, United States, wof:85688543>]
# Tempe, AZ ~ [CityMatch<Tempe, Arizona, United States, wof:85917469>]
# Madison, WI ~ [CityMatch<Madison, Wisconsin, United States, wof:101732721>]
# Santa Monica, CA ~ [CityMatch<Santa Monica, California, United States, wof:85923817>]
# New Hampshire, USA ~ [StateMatch<New Hampshire, United States, wof:85688689>]
# Reno, NV ~ [CityMatch<Reno, Nevada, United States, wof:85974779>]
# Alexandria, VA ~ [CityMatch<Alexandria, Virginia, United States, wof:1125864515>, CityMatch<Alexandria, Virginia, United States, wof:101728581>]
# Mobile, AL ~ [CityMatch<Mobile, Alabama, United States, wof:85913749>]
# Denver ~ [CityMatch<Denver, Colorado, United States, wof:85928879>]
# Syracuse, NY ~ [CityMatch<Syracuse, New York, United States, wof:85977785>]
# Sioux Falls, SD ~ [CityMatch<Sioux Falls, South Dakota, United States, wof:101721785>]
# Providence, RI ~ [CityMatch<Providence, Rhode Island, United States, wof:101720567>]
# Iowa ~ [StateMatch<Iowa, United States, wof:85688713>]
# Savannah, GA ~ [CityMatch<Savannah, Georgia, United States, wof:85936939>]
# Compton, CA ~ [CityMatch<Compton, California, United States, wof:85923663>]
# Philly ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Minneapolis ~ [CityMatch<Minneapolis, Minnesota, United States, wof:85969169>]
# West Palm Beach, FL ~ [CityMatch<West Palm Beach, Florida, United States, wof:85931945>]
# St. Louis, MO ~ [CityMatch<St. Louis, Missouri, United States, wof:85971343>]
# Ann Arbor, MI ~ [CityMatch<Ann Arbor, Michigan, United States, wof:85951859>]
# Boulder, CO ~ [CityMatch<Boulder, Colorado, United States, wof:85929877>]
# Berkeley, CA ~ [CityMatch<Berkeley, California, United States, wof:85921915>]
# Columbus, Ohio ~ [CityMatch<Columbus, Ohio, United States, wof:101712381>]
# New Mexico, USA ~ [StateMatch<New Mexico, United States, wof:85688493>]
# Toledo, OH ~ [CityMatch<Toledo, Ohio, United States, wof:101712039>]
# Tacoma, WA ~ [CityMatch<Tacoma, Washington, United States, wof:101730275>]
# DC ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>]
# Newark, NJ ~ [CityMatch<Newark, New Jersey, United States, wof:85975279>]
# HTX ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Oklahoma ~ [StateMatch<Oklahoma, United States, wof:85688585>]
# Arlington, VA ~ [CityMatch<Arlington, Virginia, United States, wof:1125927043>, CityMatch<Arlington, Virginia, United States, wof:101729469>, CityMatch<Arlington, Virginia, United States, wof:1125869831>]
# Gainesville, FL ~ [CityMatch<Gainesville, Florida, United States, wof:85932213>]
# Miami, Florida ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Cambridge, MA ~ [CityMatch<Cambridge, Massachusetts, United States, wof:85950329>]
# Lincoln, NE ~ [CityMatch<Lincoln, Nebraska, United States, wof:85973555>, CityMatch<Lincoln, Nebraska, United States, wof:1125899387>]
# Eugene, OR ~ [CityMatch<Eugene, Oregon, United States, wof:101716261>]
# New York ~ [CityMatch<New York, New York, United States, wof:85977539>, StateMatch<New York, United States, wof:85688543>]
# Mesa, AZ ~ [CityMatch<Mesa, Arizona, United States, wof:85917491>]
# Denton, TX ~ [CityMatch<Denton, Texas, United States, wof:101724431>]
# Arkansas ~ [StateMatch<Arkansas, United States, wof:85688549>]
# Norfolk, VA ~ [CityMatch<Norfolk, Virginia, United States, wof:101728769>, CityMatch<Norfolk, Virginia, United States, wof:1126057253>]
# Akron, OH ~ [CityMatch<Akron, Ohio, United States, wof:101713359>]
# Missouri ~ [StateMatch<Missouri, United States, wof:85688661>]
# Boise, ID ~ [CityMatch<Boise, Idaho, United States, wof:1141909333>]
# Palo Alto, CA ~ [CityMatch<Palo Alto, California, United States, wof:85922351>]
# Gotham ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Cleveland, Ohio ~ [CityMatch<Cleveland, Ohio, United States, wof:101712563>]
# Atlanta, Georgia ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Anaheim, CA ~ [CityMatch<Anaheim, California, United States, wof:85923167>]
# Des Moines, IA ~ [CityMatch<Des Moines, Iowa, United States, wof:85944061>]
# California ~ [StateMatch<California, United States, wof:85688637>]
# Rhode Island, USA ~ [StateMatch<Rhode Island, United States, wof:85688509>]
# Huntsville, AL ~ [CityMatch<Huntsville, Alabama, United States, wof:85913601>]
# San Marcos, TX ~ [CityMatch<San Marcos, Texas, United States, wof:101724573>]
# Little Rock, AR ~ [CityMatch<Little Rock, Arkansas, United States, wof:85921265>]
# htx ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# College Station, TX ~ [CityMatch<College Station, Texas, United States, wof:101726003>]
# Lubbock, TX ~ [CityMatch<Lubbock, Texas, United States, wof:101725261>]
# Irvine, CA ~ [CityMatch<Irvine, California, United States, wof:85923131>]
# San Antonio ~ [CityMatch<San Antonio, Texas, United States, wof:101724653>]
# Hollywood, FL ~ [CityMatch<Hollywood, Florida, United States, wof:85932381>]
# St. Louis ~ [CityMatch<St. Louis, Missouri, United States, wof:85971343>]
# Phoenix ~ [CityMatch<Phoenix, Arizona, United States, wof:85917479>]
# Jersey City, NJ ~ [CityMatch<Jersey City, New Jersey, United States, wof:85975295>]
# Columbia, SC ~ [CityMatch<Columbia, South Carolina, United States, wof:101720793>]
# Fayetteville, NC ~ [CityMatch<Fayetteville, North Carolina, United States, wof:85981411>]
# Cleveland ~ [CityMatch<Cleveland, Ohio, United States, wof:101712563>]
# texas ~ [StateMatch<Texas, United States, wof:85688753>]
# Maine ~ [StateMatch<Maine, United States, wof:85688769>]
# Fort Wayne, IN ~ [CityMatch<Fort Wayne, Indiana, United States, wof:85942149>]
# Staten Island, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Athens, GA ~ [CityMatch<Athens, Georgia, United States, wof:85936177>, CityMatch<Athens, Georgia, United States, wof:1141906837>]
# Lexington, KY ~ [CityMatch<Lexington, Kentucky, United States, wof:1125778955>, CityMatch<Lexington, Kentucky, United States, wof:1141908699>]
# los angeles ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Orlando ~ [CityMatch<Orlando, Florida, United States, wof:85933091>]
# Columbus ~ [CityMatch<Columbus, Ohio, United States, wof:101712381>]
# Chicago, Illinois ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# St Petersburg, FL ~ [CityMatch<St. Petersburg, Florida, United States, wof:85931833>]
# Greenville, SC ~ [CityMatch<Greenville, South Carolina, United States, wof:101721075>]
# Montgomery, AL ~ [CityMatch<Montgomery, Alabama, United States, wof:85913947>]
# Seattle, Washington ~ [CityMatch<Seattle, Washington, United States, wof:101730401>]
# Denver, Colorado ~ [CityMatch<Denver, Colorado, United States, wof:85928879>]
# Kansas ~ [StateMatch<Kansas, United States, wof:85688555>]
# Ontario, CA ~ [CityMatch<Ontario, California, United States, wof:85923933>]
# Hollywood ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Asheville, NC ~ [CityMatch<Asheville, North Carolina, United States, wof:85981171>]
# Pasadena, CA ~ [CityMatch<Pasadena, California, United States, wof:85923487>]
# bay area ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# San Francisco Bay Area ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Spokane, WA ~ [CityMatch<Spokane, Washington, United States, wof:101730021>]
# Lafayette, LA ~ [CityMatch<Lafayette, Louisiana, United States, wof:85948377>]
# Los Angeles ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Jackson, MS ~ [CityMatch<Jackson, Mississippi, United States, wof:85969693>]
# Stockton, CA ~ [CityMatch<Stockton, California, United States, wof:85923257>, CityMatch<Stockton, California, United States, wof:1141906831>]
# Chicago ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# St Paul, MN ~ [CityMatch<St. Paul, Minnesota, United States, wof:85953191>]
# San Antonio, Texas ~ [CityMatch<San Antonio, Texas, United States, wof:101724653>]
# Nashville ~ [CityMatch<Nashville, Tennessee, United States, wof:101723183>]
# Hawaii ~ [StateMatch<Hawaii, United States, wof:85688671>]
# Plano, TX ~ [CityMatch<Plano, Texas, United States, wof:101724389>]
# Las Vegas, Nevada ~ [CityMatch<Las Vegas, Nevada, United States, wof:85974801>]
# Anchorage, AK ~ [CityMatch<Anchorage, Alaska, United States, wof:85915707>]
# Norman, OK ~ [CityMatch<Norman, Oklahoma, United States, wof:101714727>]
# Austin ~ [CityMatch<Austin, Texas, United States, wof:101724577>]
# Portland ~ [CityMatch<Portland, Oregon, United States, wof:101715829>]
# Vancouver, WA ~ [CityMatch<Vancouver, Washington, United States, wof:101730071>]
# Boca Raton, FL ~ [CityMatch<Boca Raton, Florida, United States, wof:85932083>]
# Tuscaloosa, AL ~ [CityMatch<Tuscaloosa, Alabama, United States, wof:85914453>]
# Malibu, CA ~ [CityMatch<Malibu, California, United States, wof:85923509>]
# florida ~ [StateMatch<Florida, United States, wof:85688651>]
# Santa Cruz, CA ~ [CityMatch<Santa Cruz, California, United States, wof:85921769>]
# ohio ~ [StateMatch<Ohio, United States, wof:85688485>]
# TEXAS ~ [StateMatch<Texas, United States, wof:85688753>]
# Alaska, USA ~ [StateMatch<Alaska, United States, wof:85688573>]
# Montana, USA ~ [StateMatch<Montana, United States, wof:85688617>]
# Cincinnati ~ [CityMatch<Cincinnati, Ohio, United States, wof:101712203>]
# Milwaukee ~ [CityMatch<Milwaukee, Wisconsin, United States, wof:101732987>]
# Charlotte ~ [CityMatch<Charlotte, North Carolina, United States, wof:85981333>]
# Texas ~ [StateMatch<Texas, United States, wof:85688753>]
# Idaho ~ [StateMatch<Idaho, United States, wof:85688657>]
# Overland Park, KS ~ [CityMatch<Overland Park, Kansas, United States, wof:85945755>]
# Pensacola, FL ~ [CityMatch<Pensacola, Florida, United States, wof:85933005>]
# Green Bay, WI ~ [CityMatch<Green Bay, Wisconsin, United States, wof:101732365>]
# Idaho, USA ~ [StateMatch<Idaho, United States, wof:85688657>]
# Winston-Salem, NC ~ [CityMatch<Winston-Salem, North Carolina, United States, wof:85980715>]
# New Haven, CT ~ [CityMatch<New Haven, Connecticut, United States, wof:85930897>]
# Oklahoma City ~ [CityMatch<Oklahoma City, Oklahoma, United States, wof:101714461>]
# Vermont, USA ~ [StateMatch<Vermont, United States, wof:85688763>]
# Rhode Island ~ [StateMatch<Rhode Island, United States, wof:85688509>]
# Murfreesboro, TN ~ [CityMatch<Murfreesboro, Tennessee, United States, wof:101723111>]
# Hell, MI ~ [CityMatch<Hell, Michigan, United States, wof:1126047335>]
# Huntington Beach, CA ~ [CityMatch<Huntington Beach, California, United States, wof:85923137>]
# Myrtle Beach, SC ~ [CityMatch<Myrtle Beach, South Carolina, United States, wof:101720677>]
# Henderson, NV ~ [CityMatch<Henderson, Nevada, United States, wof:85974803>]
# Morgantown, WV ~ [CityMatch<Morgantown, West Virginia, United States, wof:101731747>]
# Sacramento ~ [CityMatch<Sacramento, California, United States, wof:85922845>]
# Augusta, GA ~ [CityMatch<Augusta, Georgia, United States, wof:85936989>, CityMatch<Augusta, Georgia, United States, wof:1141908695>]
# Florida ~ [StateMatch<Florida, United States, wof:85688651>]
# New Hampshire ~ [StateMatch<New Hampshire, United States, wof:85688689>]
# Tampa ~ [CityMatch<Tampa, Florida, United States, wof:85931789>]
# Hollywood, CA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Burbank, CA ~ [CityMatch<Burbank, California, United States, wof:85923691>, CityMatch<Burbank, California, United States, wof:85925501>]
# Fort Myers, FL ~ [CityMatch<Fort Myers, Florida, United States, wof:85932609>]
# District of Columbia, USA ~ [StateMatch<District of Columbia, United States, wof:85688741>]
# Sarasota, FL ~ [CityMatch<Sarasota, Florida, United States, wof:85932709>]
# West Hollywood, CA ~ [CityMatch<West Hollywood, California, United States, wof:85923767>]
# Springfield, MA ~ [CityMatch<Springfield, Massachusetts, United States, wof:85950393>]
# Naples, FL ~ [CityMatch<Naples, Florida, United States, wof:85931799>]
# Santa Barbara, CA ~ [CityMatch<Santa Barbara, California, United States, wof:85921779>]
# Atlanta, Ga ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Worcester, MA ~ [CityMatch<Worcester, Massachusetts, United States, wof:85950375>]
# Albany, NY ~ [CityMatch<Albany, New York, United States, wof:85977967>]
# miami ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Fargo, ND ~ [CityMatch<Fargo, North Dakota, United States, wof:85982177>]
# Kalamazoo, MI ~ [CityMatch<Kalamazoo, Michigan, United States, wof:85950985>]
# Phoenix, Arizona ~ [CityMatch<Phoenix, Arizona, United States, wof:85917479>]
# Cincinnati, Ohio ~ [CityMatch<Cincinnati, Ohio, United States, wof:101712203>]
# Oxnard, CA ~ [CityMatch<Oxnard, California, United States, wof:85923231>]
# Shreveport, LA ~ [CityMatch<Shreveport, Louisiana, United States, wof:85947819>]
# Charlottesville, VA ~ [CityMatch<Charlottesville, Virginia, United States, wof:101728535>, CityMatch<Charlottesville, Virginia, United States, wof:1125786039>]
# Frisco, TX ~ [CityMatch<Frisco, Texas, United States, wof:101724387>]
# Chandler, AZ ~ [CityMatch<Chandler, Arizona, United States, wof:85917533>]
# Fort Collins, CO ~ [CityMatch<Fort Collins, Colorado, United States, wof:85929679>]
# Orlando, Florida ~ [CityMatch<Orlando, Florida, United States, wof:85933091>]
# Bellevue, WA ~ [CityMatch<Bellevue, Washington, United States, wof:101730457>]
# Chesapeake, VA ~ [CityMatch<Chesapeake, Virginia, United States, wof:101728797>]
# Killeen, TX ~ [CityMatch<Killeen, Texas, United States, wof:101725403>]
# Roanoke, VA ~ [CityMatch<Roanoke, Virginia, United States, wof:101728747>, CityMatch<Roanoke, Virginia, United States, wof:1125786091>]
# Inglewood, CA ~ [CityMatch<Inglewood, California, United States, wof:85923577>]
# NYC ~ [CityMatch<New York, New York, United States, wof:85977539>]
# San Diego, California ~ [CityMatch<San Diego, California, United States, wof:85922227>]
# Houston TX ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Mississippi ~ [StateMatch<Mississippi, United States, wof:85688579>]
# Lansing, MI ~ [CityMatch<Lansing, Michigan, United States, wof:85951849>]
# Gilbert, AZ ~ [CityMatch<Gilbert, Arizona, United States, wof:85917513>]
# Columbus, GA ~ [CityMatch<Columbus, Georgia, United States, wof:85936243>]
# Clearwater, FL ~ [CityMatch<Clearwater, Florida, United States, wof:85931903>]
# Daytona Beach, FL ~ [CityMatch<Daytona Beach, Florida, United States, wof:85932697>]
# Nevada ~ [StateMatch<Nevada, United States, wof:85688531>]
# houston ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Fontana, CA ~ [CityMatch<Fontana, California, United States, wof:85923901>]
# Evansville, IN ~ [CityMatch<Evansville, Indiana, United States, wof:85942147>]
# Washington D.C. ~ [CityMatch<Washington, District of Columbia, United States, wof:85931779>]
# San Jose ~ [CityMatch<San Jose, California, United States, wof:85922347>]
# Erie, PA ~ [CityMatch<Erie, Pennsylvania, United States, wof:101718253>]
# Chapel Hill, NC ~ [CityMatch<Chapel Hill, North Carolina, United States, wof:85980563>]
# Amarillo, TX ~ [CityMatch<Amarillo, Texas, United States, wof:101724103>]
# york pa ~ [CityMatch<York, Pennsylvania, United States, wof:101717279>]
# Long Beach ~ [CityMatch<Long Beach, California, United States, wof:85923525>]
# RVA ~ [CityMatch<Richmond, Virginia, United States, wof:101728675>]
# Buffalo ~ [CityMatch<Buffalo, New York, United States, wof:85978023>]
# Waco, TX ~ [CityMatch<Waco, Texas, United States, wof:101723433>]
# Newport News, VA ~ [CityMatch<Newport News, Virginia, United States, wof:101729041>]
# Tyler, TX ~ [CityMatch<Tyler, Texas, United States, wof:101723901>]
# Tampa, Florida ~ [CityMatch<Tampa, Florida, United States, wof:85931789>]
# Modesto, CA ~ [CityMatch<Modesto, California, United States, wof:85922777>]
# Rancho Cucamonga, CA ~ [CityMatch<Rancho Cucamonga, California, United States, wof:85923937>]
# Oceanside, CA ~ [CityMatch<Oceanside, California, United States, wof:85922239>]
# Newport Beach, CA ~ [CityMatch<Newport Beach, California, United States, wof:85923075>]
# Brooklyn, New York ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Paterson, NJ ~ [CityMatch<Paterson, New Jersey, United States, wof:85975481>]
# Iowa City, IA ~ [CityMatch<Iowa City, Iowa, United States, wof:85944185>]
# Moreno Valley, CA ~ [CityMatch<Moreno Valley, California, United States, wof:85923379>]
# Jacksonville Beach, FL ~ [CityMatch<Jacksonville Beach, Florida, United States, wof:85932543>]
# Delaware ~ [StateMatch<Delaware, United States, wof:85688611>]
# Albuquerque ~ [CityMatch<Albuquerque, New Mexico, United States, wof:85976715>]
# San Bernardino, CA ~ [CityMatch<San Bernardino, California, United States, wof:85923951>]
# East Lansing, MI ~ [CityMatch<East Lansing, Michigan, United States, wof:85951847>]
# Yonkers, NY ~ [CityMatch<Yonkers, New York, United States, wof:85978759>]
# McKinney, TX ~ [CityMatch<Mckinney, Texas, United States, wof:101726035>]
# Fort Worth ~ [CityMatch<Fort Worth, Texas, United States, wof:101724443>]
# Rockford, IL ~ [CityMatch<Rockford, Illinois, United States, wof:85939829>]
# McAllen, TX ~ [CityMatch<Mcallen, Texas, United States, wof:101723551>]
# Irving, TX ~ [CityMatch<Irving, Texas, United States, wof:101725697>]
# Redmond, WA ~ [CityMatch<Redmond, Washington, United States, wof:101730409>]
# Lancaster, PA ~ [CityMatch<Lancaster, Pennsylvania, United States, wof:101718643>]
# Cary, NC ~ [CityMatch<Cary, North Carolina, United States, wof:85980827>]
# Silver Spring, MD ~ [CityMatch<Silver Spring, Maryland, United States, wof:85950277>]
# Tucson ~ [CityMatch<Tucson, Arizona, United States, wof:85917235>]
# Olympia, WA ~ [CityMatch<Olympia, Washington, United States, wof:101730335>]
# Lakeland, FL ~ [CityMatch<Lakeland, Florida, United States, wof:85933319>]
# Nebraska ~ [StateMatch<Nebraska, United States, wof:85688563>]
# Macon, GA ~ [CityMatch<Macon, Georgia, United States, wof:85936517>]
# Santa Ana, CA ~ [CityMatch<Santa Ana, California, United States, wof:85923049>]
# Houston, Tx ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Salem, OR ~ [CityMatch<Salem, Oregon, United States, wof:101716049>]
# Orange, CA ~ [CityMatch<Orange, California, United States, wof:85923071>]
# Flint, MI ~ [CityMatch<Flint, Michigan, United States, wof:85951927>]
# Santa Clara, CA ~ [CityMatch<Santa Clara, California, United States, wof:85922341>]
# Baltimore, Maryland ~ [CityMatch<Baltimore, Maryland, United States, wof:85949461>]
# Joliet, IL ~ [CityMatch<Joliet, Illinois, United States, wof:85940583>]
# Boston, Massachusetts ~ [CityMatch<Boston, Massachusetts, United States, wof:85950361>]
# Katy, TX ~ [CityMatch<Katy, Texas, United States, wof:101723983>]
# Portland, ME ~ [CityMatch<Portland, Maine, United States, wof:85948877>]
# Fresno ~ [CityMatch<Fresno, California, United States, wof:85922995>]
# Naperville, IL ~ [CityMatch<Naperville, Illinois, United States, wof:85940205>]
# St. Paul, MN ~ [CityMatch<St. Paul, Minnesota, United States, wof:85953191>]
# West Virginia ~ [StateMatch<West Virginia, United States, wof:85688589>]
# Springfield, IL ~ [CityMatch<Springfield, Illinois, United States, wof:85940429>]
# Baton Rouge ~ [CityMatch<Baton Rouge, Louisiana, United States, wof:85948205>]
# Cupertino, CA ~ [CityMatch<Cupertino, California, United States, wof:85922393>]
# Topeka, KS ~ [CityMatch<Topeka, Kansas, United States, wof:85945467>]
# Oakland ~ [CityMatch<Oakland, California, United States, wof:85921881>]
# new york city ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Marietta, GA ~ [CityMatch<Marietta, Georgia, United States, wof:85936135>]
# Santa Clarita, CA ~ [CityMatch<Santa Clarita, California, United States, wof:85923827>]
# Allentown, PA ~ [CityMatch<Allentown, Pennsylvania, United States, wof:101717925>]
# Huntington, WV ~ [CityMatch<Huntington, West Virginia, United States, wof:101731553>]
# Springfield, MO ~ [CityMatch<Springfield, Missouri, United States, wof:85971363>]
# Hampton, VA ~ [CityMatch<Hampton, Virginia, United States, wof:101728661>, CityMatch<Hampton, Virginia, United States, wof:1125786071>]
# Lowell, MA ~ [CityMatch<Lowell, Massachusetts, United States, wof:85950327>]
# Dayton, Ohio ~ [CityMatch<Dayton, Ohio, United States, wof:101712161>]
# Wilmington, NC ~ [CityMatch<Wilmington, North Carolina, United States, wof:85980683>]
# Santa Rosa, CA ~ [CityMatch<Santa Rosa, California, United States, wof:85922693>]
# Mountain View, CA ~ [CityMatch<Mountain View, California, United States, wof:85922355>, CityMatch<Mountain View, California, United States, wof:85925123>]
# Edmond, OK ~ [CityMatch<Edmond, Oklahoma, United States, wof:101714451>]
# Provo, UT ~ [CityMatch<Provo, Utah, United States, wof:101727863>]
# Fullerton, CA ~ [CityMatch<Fullerton, California, United States, wof:85923145>]
# Colorado Springs ~ [CityMatch<Colorado Springs, Colorado, United States, wof:85929457>]
# ny ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Louisville ~ [CityMatch<Louisville, Kentucky, United States, wof:85947523>]
# South Dakota, USA ~ [StateMatch<South Dakota, United States, wof:85688693>]
# New Mexico ~ [StateMatch<New Mexico, United States, wof:85688493>]
# Garland, TX ~ [CityMatch<Garland, Texas, United States, wof:101724045>]
# new jersey ~ [StateMatch<New Jersey, United States, wof:85688607>]
# SF Bay Area ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# North Las Vegas, NV ~ [CityMatch<North Las Vegas, Nevada, United States, wof:85974799>]
# Vallejo, CA ~ [CityMatch<Vallejo, California, United States, wof:85922643>]
# boston ~ [CityMatch<Boston, Massachusetts, United States, wof:85950361>]
# Indianapolis, Indiana ~ [CityMatch<Indianapolis, Indiana, United States, wof:85942569>]
# Pearland, TX ~ [CityMatch<Pearland, Texas, United States, wof:101725125>]
# Jacksonville, Florida ~ [CityMatch<Jacksonville, Florida, United States, wof:85932547>]
# Corona, CA ~ [CityMatch<Corona, California, United States, wof:85923413>]
# Salt Lake City, Utah ~ [CityMatch<Salt Lake City, Utah, United States, wof:101728075>]
# Youngstown, OH ~ [CityMatch<Youngstown, Ohio, United States, wof:101712497>]
# Temecula, CA ~ [CityMatch<Temecula, California, United States, wof:85923337>]
# Clarksville, TN ~ [CityMatch<Clarksville, Tennessee, United States, wof:101722759>]
# San Francisco, California ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Bellingham, WA ~ [CityMatch<Bellingham, Washington, United States, wof:101730153>]
# michigan ~ [StateMatch<Michigan, United States, wof:85688599>]
# Decatur, GA ~ [CityMatch<Decatur, Georgia, United States, wof:85936441>]
# State College, PA ~ [CityMatch<State College, Pennsylvania, United States, wof:101718127>]
# Detroit, Michigan ~ [CityMatch<Detroit, Michigan, United States, wof:85951091>]
# STL ~ [CityMatch<St. Louis, Missouri, United States, wof:85971343>]
# Alaska ~ [StateMatch<Alaska, United States, wof:85688573>]
# Carlsbad, CA ~ [CityMatch<Carlsbad, California, United States, wof:85922291>]
# Cedar Rapids, IA ~ [CityMatch<Cedar Rapids, Iowa, United States, wof:85944253>]
# Hayward, CA ~ [CityMatch<Hayward, California, United States, wof:85921895>]
# City of Angels ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Lake Charles, LA ~ [CityMatch<Lake Charles, Louisiana, United States, wof:85948165>]
# Omaha ~ [CityMatch<Omaha, Nebraska, United States, wof:85973483>]
# NOLA ~ [CityMatch<New Orleans, Louisiana, United States, wof:85948111>]
# Bloomington, IN ~ [CityMatch<Bloomington, Indiana, United States, wof:85941713>]
# Auburn, AL ~ [CityMatch<Auburn, Alabama, United States, wof:85913825>]
# Stamford, CT ~ [CityMatch<Stamford, Connecticut, United States, wof:85930787>]
# Flagstaff, AZ ~ [CityMatch<Flagstaff, Arizona, United States, wof:85917421>]
# Missoula, MT ~ [CityMatch<Missoula, Montana, United States, wof:85972703>]
# ATX ~ [CityMatch<Austin, Texas, United States, wof:101724577>]
# Wyoming, USA ~ [StateMatch<Wyoming, United States, wof:85688475>]
# St. Petersburg ~ [CityMatch<St. Petersburg, Florida, United States, wof:85931833>]
# Sunnyvale, CA ~ [CityMatch<Sunnyvale, California, United States, wof:85922333>]
# SATX ~ [CityMatch<San Antonio, Texas, United States, wof:101724653>]
# Pasadena, TX ~ [CityMatch<Pasadena, Texas, United States, wof:101726105>]
# philly ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Annapolis, MD ~ [CityMatch<Annapolis, Maryland, United States, wof:85949233>]
# Los Angeles, CA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Harrisburg, PA ~ [CityMatch<Harrisburg, Pennsylvania, United States, wof:101717693>]
# Las Cruces, NM ~ [CityMatch<Las Cruces, New Mexico, United States, wof:85976635>]
# Minneapolis, Minnesota ~ [CityMatch<Minneapolis, Minnesota, United States, wof:85969169>]
# Palm Springs, CA ~ [CityMatch<Palm Springs, California, United States, wof:85923357>]
# Odessa, TX ~ [CityMatch<Odessa, Texas, United States, wof:101723959>]
# North Dakota, USA ~ [StateMatch<North Dakota, United States, wof:85688525>]
# Anaheim ~ [CityMatch<Anaheim, California, United States, wof:85923167>]
# Columbia, MO ~ [CityMatch<Columbia, Missouri, United States, wof:85970425>]
# Raleigh ~ [CityMatch<Raleigh, North Carolina, United States, wof:85980569>]
# Fairfax, VA ~ [CityMatch<Fairfax, Virginia, United States, wof:1125885137>, CityMatch<Fairfax, Virginia, United States, wof:101728653>]
# Calabasas, CA ~ [CityMatch<Calabasas, California, United States, wof:85923687>]
# Chico, CA ~ [CityMatch<Chico, California, United States, wof:85923179>]
# PHL ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Lawrence, KS ~ [CityMatch<Lawrence, Kansas, United States, wof:85945709>]
# Palmdale, CA ~ [CityMatch<Palmdale, California, United States, wof:85923493>]
# New York City ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Kissimmee, FL ~ [CityMatch<Kissimmee, Florida, United States, wof:85932595>]
# Bowling Green, KY ~ [CityMatch<Bowling Green, Kentucky, United States, wof:85947335>]
# Charleston, WV ~ [CityMatch<Charleston, West Virginia, United States, wof:101731793>]
# Beaumont, TX ~ [CityMatch<Beaumont, Texas, United States, wof:101724989>]
# Chesapeake ~ [CityMatch<Chesapeake, Virginia, United States, wof:101728797>]
# Grand Prairie, TX ~ [CityMatch<Grand Prairie, Texas, United States, wof:101724555>]
# Newark, DE ~ [CityMatch<Newark, Delaware, United States, wof:85931551>]
# Fort Worth, Texas ~ [CityMatch<Fort Worth, Texas, United States, wof:101724443>]
# Jacksonville ~ [CityMatch<Jacksonville, Florida, United States, wof:85932547>]
# Williamsburg, VA ~ [CityMatch<Williamsburg, Virginia, United States, wof:1125768245>, CityMatch<Williamsburg, Virginia, United States, wof:101728999>]
# Mesa ~ [CityMatch<Mesa, Arizona, United States, wof:85917491>]
# Princeton, NJ ~ [CityMatch<Princeton, New Jersey, United States, wof:85975813>]
# Brownsville, TX ~ [CityMatch<Brownsville, Texas, United States, wof:101724157>]
# Athens, OH ~ [CityMatch<Athens, Ohio, United States, wof:101712889>]
# South Bend, IN ~ [CityMatch<South Bend, Indiana, United States, wof:85942439>]
# Torrance, CA ~ [CityMatch<Torrance, California, United States, wof:85923785>]
# Abilene, TX ~ [CityMatch<Abilene, Texas, United States, wof:101724139>]
# Lancaster, CA ~ [CityMatch<Lancaster, California, United States, wof:85923547>, CityMatch<Lancaster, California, United States, wof:1141908693>]
# Whittier, CA ~ [CityMatch<Whittier, California, United States, wof:85923757>]
# Montana ~ [StateMatch<Montana, United States, wof:85688617>]
# Salinas, CA ~ [CityMatch<Salinas, California, United States, wof:85922603>]
# DTX ~ [CityMatch<Dallas, Texas, United States, wof:101724385>]
# La La Land ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Jersey City ~ [CityMatch<Jersey City, New Jersey, United States, wof:85975295>]
# Muncie, IN ~ [CityMatch<Muncie, Indiana, United States, wof:85941463>]
# Houston Texas ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# El Paso ~ [CityMatch<El Paso, Texas, United States, wof:101724863>]
# Spartanburg, SC ~ [CityMatch<Spartanburg, South Carolina, United States, wof:101721215>]
# Huntsville, TX ~ [CityMatch<Huntsville, Texas, United States, wof:101724497>]
# Miami, Fl ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Atlanta ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# North Las Vegas ~ [CityMatch<North Las Vegas, Nevada, United States, wof:85974799>]
# Ypsilanti, MI ~ [CityMatch<Ypsilanti, Michigan, United States, wof:85951885>]
# Round Rock, TX ~ [CityMatch<Round Rock, Texas, United States, wof:101725087>]
# Laredo, TX ~ [CityMatch<Laredo, Texas, United States, wof:101725033>, CityMatch<Laredo, Texas, United States, wof:1141909163>]
# Scottsdale ~ [CityMatch<Scottsdale, Arizona, United States, wof:85917475>]
# Champaign, IL ~ [CityMatch<Champaign, Illinois, United States, wof:85938301>]
# Vermont ~ [StateMatch<Vermont, United States, wof:85688763>]
# Chicagoland ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# CLE ~ [CityMatch<Cleveland, Ohio, United States, wof:101712563>]
# Hattiesburg, MS ~ [CityMatch<Hattiesburg, Mississippi, United States, wof:85969939>]
# Omaha, Nebraska ~ [CityMatch<Omaha, Nebraska, United States, wof:85973483>]
# Chicago, IL ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# Michigan ~ [StateMatch<Michigan, United States, wof:85688599>]
# Fort Wayne ~ [CityMatch<Fort Wayne, Indiana, United States, wof:85942149>]
# Nashville, Tennessee ~ [CityMatch<Nashville, Tennessee, United States, wof:1141909337>, CityMatch<Nashville, Tennessee, United States, wof:101723183>]
# Bridgeport, CT ~ [CityMatch<Bridgeport, Connecticut, United States, wof:85930811>]
# Surprise, AZ ~ [CityMatch<Surprise, Arizona, United States, wof:85917473>]
# Birmingham, Alabama ~ [CityMatch<Birmingham, Alabama, United States, wof:85914465>]
# Vegas ~ [CityMatch<Las Vegas, Nevada, United States, wof:85974801>]
# atlanta ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Scranton, PA ~ [CityMatch<Scranton, Pennsylvania, United States, wof:101718305>]
# Fremont, CA ~ [CityMatch<Fremont, California, United States, wof:85921899>]
# Dallas, Tx ~ [CityMatch<Dallas, Texas, United States, wof:101724385>]
# Stillwater, OK ~ [CityMatch<Stillwater, Oklahoma, United States, wof:101714359>]
# Victorville, CA ~ [CityMatch<Victorville, California, United States, wof:85923967>]
# Riverside ~ [CityMatch<Riverside, California, United States, wof:85923345>]
# The Woodlands, TX ~ [CityMatch<The Woodlands, Texas, United States, wof:101727415>]
# Tucson, Arizona ~ [CityMatch<Tucson, Arizona, United States, wof:85917235>]
# Honolulu, Hawaii ~ [CityMatch<Honolulu, Hawaii, United States, wof:1141909415>]
# Downey, CA ~ [CityMatch<Downey, California, United States, wof:85923637>]
# Visalia, CA ~ [CityMatch<Visalia, California, United States, wof:85922461>]
# Manchester, NH ~ [CityMatch<Manchester, New Hampshire, United States, wof:85975081>]
# Tulsa ~ [CityMatch<Tulsa, Oklahoma, United States, wof:101714287>]
# Pembroke Pines, FL ~ [CityMatch<Pembroke Pines, Florida, United States, wof:85932299>]
# Miami ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Edinburg, TX ~ [CityMatch<Edinburg, Texas, United States, wof:101723563>]
# Kent, OH ~ [CityMatch<Kent, Ohio, United States, wof:101711887>]
# Houston, TX ~ [CityMatch<Houston, Texas, United States, wof:101725629>]
# Pomona, CA ~ [CityMatch<Pomona, California, United States, wof:85923479>]
# seattle ~ [CityMatch<Seattle, Washington, United States, wof:101730401>]
# San Francisco, Ca ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Oxford, MS ~ [CityMatch<Oxford, Mississippi, United States, wof:85969753>]
# Statesboro, GA ~ [CityMatch<Statesboro, Georgia, United States, wof:85935999>]
# Fredericksburg, VA ~ [CityMatch<Fredericksburg, Virginia, United States, wof:101728699>, CityMatch<Fredericksburg, Virginia, United States, wof:1125786053>]
# Davenport, IA ~ [CityMatch<Davenport, Iowa, United States, wof:85944193>]
# West Covina, CA ~ [CityMatch<West Covina, California, United States, wof:85923771>]
# Lubbock ~ [CityMatch<Lubbock, Texas, United States, wof:101725261>]
# Spokane ~ [CityMatch<Spokane, Washington, United States, wof:101730021>]
# Ithaca, NY ~ [CityMatch<Ithaca, New York, United States, wof:85978779>]
# Reno ~ [CityMatch<Reno, Nevada, United States, wof:85974779>]
# Bay Area, California ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Manhattan ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Hialeah ~ [CityMatch<Hialeah, Florida, United States, wof:85933653>]
# atl ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Pompano Beach, FL ~ [CityMatch<Pompano Beach, Florida, United States, wof:85932289>]
# Spring, TX ~ [CityMatch<Spring, Texas, United States, wof:101727525>]
# Burlington, VT ~ [CityMatch<Burlington, Vermont, United States, wof:101728319>]
# Elk Grove, CA ~ [CityMatch<Elk Grove, California, United States, wof:85922869>]
# New Jersey ~ [StateMatch<New Jersey, United States, wof:85688607>]
# Stockton ~ [CityMatch<Stockton, California, United States, wof:85923257>]
# Orem, UT ~ [CityMatch<Orem, Utah, United States, wof:101727865>]
# Frederick, MD ~ [CityMatch<Frederick, Maryland, United States, wof:85949385>]
# Wichita Falls, TX ~ [CityMatch<Wichita Falls, Texas, United States, wof:101725325>]
# Clovis, CA ~ [CityMatch<Clovis, California, United States, wof:85923015>]
# Kennesaw, GA ~ [CityMatch<Kennesaw, Georgia, United States, wof:85936133>]
# St. Louis, Missouri ~ [CityMatch<St. Louis, Missouri, United States, wof:85971343>]
# maryland ~ [StateMatch<Maryland, United States, wof:85688501>]
# Salem, MA ~ [CityMatch<Salem, Massachusetts, United States, wof:85950403>]
# York, PA ~ [CityMatch<York, Pennsylvania, United States, wof:101717279>]
# Ocala, FL ~ [CityMatch<Ocala, Florida, United States, wof:85932433>]
# sjc ~ [CityMatch<San Jose, California, United States, wof:85922347>]
# ...
# Macon,Ga ~ [CityMatch<Macon, Georgia, United States, wof:85936517>]
# New York, NY ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Gas City, IN ~ [CityMatch<Gas City, Indiana, United States, wof:85941703>]
# Pemberton, NJ ~ [CityMatch<Pemberton, New Jersey, United States, wof:85975531>]
# Merriam, KS ~ [CityMatch<Merriam, Kansas, United States, wof:85945745>]
# Grafton, WI ~ [CityMatch<Grafton, Wisconsin, United States, wof:101732543>]
# Mansfield, PA ~ [CityMatch<Mansfield, Pennsylvania, United States, wof:101717063>]
# Harlem, GA ~ [CityMatch<Harlem, Georgia, United States, wof:85935975>]
# Williamsport, MD ~ [CityMatch<Williamsport, Maryland, United States, wof:85949153>]
# Holly Springs, MS ~ [CityMatch<Holly Springs, Mississippi, United States, wof:85969535>]
# Lindenwold, NJ ~ [CityMatch<Lindenwold, New Jersey, United States, wof:85975649>]
# Chattanooga, Tn ~ [CityMatch<Chattanooga, Tennessee, United States, wof:101723043>]
# mesa ~ [CityMatch<Mesa, Arizona, United States, wof:85917491>]
# Detroit, Michigan. ~ [CityMatch<Detroit, Michigan, United States, wof:85951091>]
# Colma, CA ~ [CityMatch<Colma, California, United States, wof:85922533>]
# Buffalo ny ~ [CityMatch<Buffalo, New York, United States, wof:85978023>]
# Independence, LA ~ [CityMatch<Independence, Louisiana, United States, wof:85948467>]
# Magnolia, NJ ~ [CityMatch<Magnolia, New Jersey, United States, wof:85975647>]
# Litchfield, CT ~ [CityMatch<Litchfield, Connecticut, United States, wof:85930833>]
# Central Louisiana ~ [CityMatch<Central, Louisiana, United States, wof:85948201>]
# Refugio, TX ~ [CityMatch<Refugio, Texas, United States, wof:101723999>]
# Jonesboro, LA ~ [CityMatch<Jonesboro, Louisiana, United States, wof:85948021>]
# Laguna Niguel, California ~ [CityMatch<Laguna Niguel, California, United States, wof:85923115>]
# MA, US ~ [StateMatch<Massachusetts, United States, wof:85688645>]
# okc ~ [CityMatch<Oklahoma City, Oklahoma, United States, wof:101714461>]
# New Haven CT ~ [CityMatch<New Haven, Connecticut, United States, wof:85930897>]
# Summerfield, FL ~ [CityMatch<Summerfield, Florida, United States, wof:1125765497>]
# Dousman Wisconsin ~ [CityMatch<Dousman, Wisconsin, United States, wof:101733477>]
# New Haven, CT, USA ~ [CityMatch<New Haven, Connecticut, United States, wof:85930897>]
# Harrison, TN ~ [CityMatch<Harrison, Tennessee, United States, wof:101723293>]
# Glendive, MT ~ [CityMatch<Glendive, Montana, United States, wof:85972825>]
# tampa florida ~ [CityMatch<Tampa, Florida, United States, wof:85931789>]
# South Point, OH ~ [CityMatch<South Point, Ohio, United States, wof:101713269>]
# Atlanta,GA ~ [CityMatch<Atlanta, Georgia, United States, wof:85936429>]
# Niagara Falls NY ~ [CityMatch<Niagara Falls, New York, United States, wof:85978259>]
# Cortland, OH ~ [CityMatch<Cortland, Ohio, United States, wof:101713285>]
# Ann Arbor, MI, USA ~ [CityMatch<Ann Arbor, Michigan, United States, wof:85951859>]
# beantown ~ [CityMatch<Boston, Massachusetts, United States, wof:85950361>]
# Fishkill, NY ~ [CityMatch<Fishkill, New York, United States, wof:85977831>]
# Lawrence, NJ ~ [CityMatch<Lawrence, New Jersey, United States, wof:1125808417>]
# Stewartville, MN ~ [CityMatch<Stewartville, Minnesota, United States, wof:85953503>]
# The Acreage, FL ~ [CityMatch<The Acreage, Florida, United States, wof:85934135>]
# Des Moines, Iowa, USA ~ [CityMatch<Des Moines, Iowa, United States, wof:85944061>]
# Boothwyn, PA ~ [CityMatch<Boothwyn, Pennsylvania, United States, wof:101720035>]
# Trenton, GA ~ [CityMatch<Trenton, Georgia, United States, wof:85935989>]
# Oviedo, Florida ~ [CityMatch<Oviedo, Florida, United States, wof:85932129>]
# Salem, NJ ~ [CityMatch<Salem, New Jersey, United States, wof:85975351>]
# DALLAS TEXAS ~ [CityMatch<Dallas, Texas, United States, wof:101724385>]
# Yonkers NY ~ [CityMatch<Yonkers, New York, United States, wof:85978759>]
# Pinecrest, FL ~ [CityMatch<Pinecrest, Florida, United States, wof:85933579>]
# Vinton, VA ~ [CityMatch<Vinton, Virginia, United States, wof:101728545>, CityMatch<Vinton, Virginia, United States, wof:1126038947>]
# Virginia Beach, VA ~ [CityMatch<Virginia Beach, Virginia, United States, wof:101728745>, CityMatch<Virginia Beach, Virginia, United States, wof:1125983951>]
# Othello, WA ~ [CityMatch<Othello, Washington, United States, wof:101730131>]
# Sunset, LA ~ [CityMatch<Sunset, Louisiana, United States, wof:85948421>]
# Tuckahoe, NY ~ [CityMatch<Tuckahoe, New York, United States, wof:85978763>, CityMatch<Tuckahoe, New York, United States, wof:85979807>]
# Fort Worth, TX, USA ~ [CityMatch<Fort Worth, Texas, United States, wof:101724443>]
# Pennington, NJ ~ [CityMatch<Pennington, New Jersey, United States, wof:85975815>]
# Lancaster, California ~ [CityMatch<Lancaster, California, United States, wof:85923547>, CityMatch<Lancaster, California, United States, wof:1141908693>]
# Atherton, CA ~ [CityMatch<Atherton, California, United States, wof:85922561>]
# Palm Beach Gardens, Florida ~ [CityMatch<Palm Beach Gardens, Florida, United States, wof:85931967>]
# Laramie, Wyoming ~ [CityMatch<Laramie, Wyoming, United States, wof:101733997>]
# PDX, OR ~ [CityMatch<Portland, Oregon, United States, wof:101715829>]
# Wilmington,NC ~ [CityMatch<Wilmington, North Carolina, United States, wof:85980683>]
# McCordsville, IN ~ [CityMatch<Mccordsville, Indiana, United States, wof:85941309>]
# Kaukauna, WI ~ [CityMatch<Kaukauna, Wisconsin, United States, wof:101732429>]
# Kearney, MO ~ [CityMatch<Kearney, Missouri, United States, wof:85972463>]
# Philadelphia, PA ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Honesdale, PA ~ [CityMatch<Honesdale, Pennsylvania, United States, wof:101717553>]
# St. Cloud, Minnesota ~ [CityMatch<St. Cloud, Minnesota, United States, wof:85952437>]
# Baraboo, WI ~ [CityMatch<Baraboo, Wisconsin, United States, wof:101733429>]
# Oxford, PA ~ [CityMatch<Oxford, Pennsylvania, United States, wof:101718593>]
# SEATTLE,WA ~ [CityMatch<Seattle, Washington, United States, wof:101730401>]
# Metter, GA ~ [CityMatch<Metter, Georgia, United States, wof:85936533>]
# West Nyack, NY ~ [CityMatch<West Nyack, New York, United States, wof:85979989>]
# Strawberry Plains, TN ~ [CityMatch<Strawberry Plains, Tennessee, United States, wof:1125806323>]
# Miami, Florida,USA ~ [CityMatch<Miami, Florida, United States, wof:85933669>]
# Los Angeles, CA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Nipomo, CA ~ [CityMatch<Nipomo, California, United States, wof:85925469>]
# Denver Colorado ~ [CityMatch<Denver, Colorado, United States, wof:85928879>]
# Tishomingo, OK ~ [CityMatch<Tishomingo, Oklahoma, United States, wof:101715119>]
# Brooklyn, New York. ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Garland Texas ~ [CityMatch<Garland, Texas, United States, wof:101724045>]
# Henderson NV ~ [CityMatch<Henderson, Nevada, United States, wof:85974803>]
# the big apple ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Montgomery, IL ~ [CityMatch<Montgomery, Illinois, United States, wof:85939797>]
# Mount Zion, IL ~ [CityMatch<Mount Zion, Illinois, United States, wof:85940069>]
# Sweet Home, OR ~ [CityMatch<Sweet Home, Oregon, United States, wof:101716165>]
# Irvine, Ca ~ [CityMatch<Irvine, California, United States, wof:85923131>]
# New Cumberland, PA ~ [CityMatch<New Cumberland, Pennsylvania, United States, wof:101716757>]
# San Antonio. ~ [CityMatch<San Antonio, Texas, United States, wof:101724653>]
# Saginaw, TX ~ [CityMatch<Saginaw, Texas, United States, wof:101723705>]
# Pomona, California ~ [CityMatch<Pomona, California, United States, wof:85923479>]
# Castle Rock, Colorado ~ [CityMatch<Castle Rock, Colorado, United States, wof:85929245>]
# Harahan, LA ~ [CityMatch<Harahan, Louisiana, United States, wof:85948297>]
# Hunt Valley, MD ~ [CityMatch<Hunt Valley, Maryland, United States, wof:1125958957>]
# South Huntington, NY ~ [CityMatch<South Huntington, New York, United States, wof:85979819>]
# bay area, ca ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Hudson Falls, NY ~ [CityMatch<Hudson Falls, New York, United States, wof:85978651>]
# Pratt, KS ~ [CityMatch<Pratt, Kansas, United States, wof:85945699>]
# Franklin Tennessee ~ [CityMatch<Franklin, Tennessee, United States, wof:101723093>]
# Bloomington, Indiana ~ [CityMatch<Bloomington, Indiana, United States, wof:85941713>]
# Salida, CA ~ [CityMatch<Salida, California, United States, wof:85926521>]
# Granbury, Texas ~ [CityMatch<Granbury, Texas, United States, wof:101723973>]
# Spencer, OK ~ [CityMatch<Spencer, Oklahoma, United States, wof:101714429>]
# Pettyville, WV ~ [CityMatch<Pettyville, West Virginia, United States, wof:1126040053>]
# Buffalo, NY, USA ~ [CityMatch<Buffalo, New York, United States, wof:85978023>]
# Hughson, CA ~ [CityMatch<Hughson, California, United States, wof:85922781>]
# Nashville, TN. ~ [CityMatch<Nashville, Tennessee, United States, wof:1141909337>, CityMatch<Nashville, Tennessee, United States, wof:101723183>]
# Boonsboro, MD ~ [CityMatch<Boonsboro, Maryland, United States, wof:85949171>]
# Wichita, KS ~ [CityMatch<Wichita, Kansas, United States, wof:85945871>]
# Stuart, Florida ~ [CityMatch<Stuart, Florida, United States, wof:85933153>]
# Cherokee, NC ~ [CityMatch<Cherokee, North Carolina, United States, wof:85981607>]
# Santa Rosa CA ~ [CityMatch<Santa Rosa, California, United States, wof:85922693>]
# Diamondhead, MS ~ [CityMatch<Diamondhead, Mississippi, United States, wof:85970309>]
# denver ~ [CityMatch<Denver, Colorado, United States, wof:85928879>]
# Santa Rosa California ~ [CityMatch<Santa Rosa, California, United States, wof:85922693>]
# Wood River, IL ~ [CityMatch<Wood River, Illinois, United States, wof:85940313>]
# New york, New york ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Boise,ID ~ [CityMatch<Boise, Idaho, United States, wof:1141909333>]
# Washington, IA ~ [CityMatch<Washington, Iowa, United States, wof:85943125>]
# Violet, LA ~ [CityMatch<Violet, Louisiana, United States, wof:85948809>]
# Zelienople, PA ~ [CityMatch<Zelienople, Pennsylvania, United States, wof:101718147>]
# Tecumseh, MI ~ [CityMatch<Tecumseh, Michigan, United States, wof:85951693>]
# Chi town ~ [CityMatch<Chicago, Illinois, United States, wof:85940195>]
# Des Moines, Iowa ~ [CityMatch<Des Moines, Iowa, United States, wof:85944061>]
# LA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Candler-McAfee, GA ~ [CityMatch<Candler-Mcafee, Georgia, United States, wof:85937249>]
# Springfield VA ~ [CityMatch<Springfield, Virginia, United States, wof:1125961801>, CityMatch<Springfield, Virginia, United States, wof:101729791>]
# Salem, Massachusetts ~ [CityMatch<Salem, Massachusetts, United States, wof:85950403>]
# Campton Hills, IL ~ [CityMatch<Campton Hills, Illinois, United States, wof:85939701>]
# Pitman, NJ ~ [CityMatch<Pitman, New Jersey, United States, wof:85975453>]
# Youngstown,Ohio ~ [CityMatch<Youngstown, Ohio, United States, wof:101712497>]
# Inwood, NY ~ [CityMatch<Inwood, New York, United States, wof:85979091>]
# Humboldt, TN ~ [CityMatch<Humboldt, Tennessee, United States, wof:101722765>]
# Independence MO ~ [CityMatch<Independence, Missouri, United States, wof:85971449>]
# Vernal, UT ~ [CityMatch<Vernal, Utah, United States, wof:101727933>]
# Ellenwood, Georgia ~ [CityMatch<Ellenwood, Georgia, United States, wof:1126054897>]
# Marietta GA ~ [CityMatch<Marietta, Georgia, United States, wof:85936135>]
# Haverstraw, NY ~ [CityMatch<Haverstraw, New York, United States, wof:85978549>]
# Williamston, MI ~ [CityMatch<Williamston, Michigan, United States, wof:85951751>]
# Corona, Ca ~ [CityMatch<Corona, California, United States, wof:85923413>]
# Quincy, WA ~ [CityMatch<Quincy, Washington, United States, wof:101730199>]
# Cazenovia, NY ~ [CityMatch<Cazenovia, New York, United States, wof:85978067>]
# the bronx ~ [CityMatch<New York, New York, United States, wof:85977539>]
# S.F Bay Area, CA. ~ [CityMatch<San Francisco, California, United States, wof:85922583>]
# Morgantown WV ~ [CityMatch<Morgantown, West Virginia, United States, wof:101731747>]
# nueva york ~ [CityMatch<New York, New York, United States, wof:85977539>]
# Plainfield, Indiana ~ [CityMatch<Plainfield, Indiana, United States, wof:85941489>]
# Philadelphia PA ~ [CityMatch<Philadelphia, Pennsylvania, United States, wof:101718083>]
# Burbank, CA, USA ~ [CityMatch<Burbank, California, United States, wof:85923691>, CityMatch<Burbank, California, United States, wof:85925501>]
# Fayetteville Arkansas ~ [CityMatch<Fayetteville, Arkansas, United States, wof:85919609>]
# Clarksville, MI ~ [CityMatch<Clarksville, Michigan, United States, wof:85951725>]
# Coppell, Texas ~ [CityMatch<Coppell, Texas, United States, wof:101724393>]
# Long Beach, CA, USA ~ [CityMatch<Long Beach, California, United States, wof:85923525>]
# Port Aransas, TX ~ [CityMatch<Port Aransas, Texas, United States, wof:101724375>]
# Trinity, NC ~ [CityMatch<Trinity, North Carolina, United States, wof:85980747>]
# Tillamook, OR ~ [CityMatch<Tillamook, Oregon, United States, wof:101715925>]
# Oklahoma ~ [StateMatch<Oklahoma, United States, wof:85688585>]
# Denton TX ~ [CityMatch<Denton, Texas, United States, wof:101724431>]
# Swanton, OH ~ [CityMatch<Swanton, Ohio, United States, wof:85983143>]
# Los Angeles,  CA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Lawrence - Kansas ~ [CityMatch<Lawrence, Kansas, United States, wof:85945709>]
# Louisa, KY ~ [CityMatch<Louisa, Kentucky, United States, wof:85947085>]
# Hull, MA ~ [CityMatch<Hull, Massachusetts, United States, wof:85950453>]
# Rushville, IN ~ [CityMatch<Rushville, Indiana, United States, wof:85942009>]
# Fairless Hills, PA ~ [CityMatch<Fairless Hills, Pennsylvania, United States, wof:101719123>]
# Calabasas, CA ~ [CityMatch<Calabasas, California, United States, wof:85923687>]
# Clearfield, PA ~ [CityMatch<Clearfield, Pennsylvania, United States, wof:101717535>]
# West Trenton, NJ ~ [CityMatch<West Trenton, New Jersey, United States, wof:1125767717>]
# Manlius, NY ~ [CityMatch<Manlius, New York, United States, wof:85977771>]
# Valdosta, Georgia ~ [CityMatch<Valdosta, Georgia, United States, wof:85936921>]
# Annandale-on-Hudson, NY ~ [CityMatch<Annandale-on-Hudson, New York, United States, wof:1125774515>]
# Nashua NH ~ [CityMatch<Nashua, New Hampshire, United States, wof:85975079>]
# Cut and Shoot, TX ~ [CityMatch<Cut and Shoot, Texas, United States, wof:101725635>]
# West Allis, Wisconsin ~ [CityMatch<West Allis, Wisconsin, United States, wof:101733091>]
# SLC,UT ~ [CityMatch<Salt Lake City, Utah, United States, wof:101728075>]
# Flint ,Mi ~ [CityMatch<Flint, Michigan, United States, wof:85951927>]
# Atlantic City, New Jersey ~ [CityMatch<Atlantic City, New Jersey, United States, wof:85975315>]
# Fairfax Station, VA ~ [CityMatch<Fairfax Station, Virginia, United States, wof:101729811>, CityMatch<Fairfax Station, Virginia, United States, wof:1125853395>]
# Grand Rapids, MI, USA ~ [CityMatch<Grand Rapids, Michigan, United States, wof:85951337>]
# Newmarket, NH ~ [CityMatch<Newmarket, New Hampshire, United States, wof:85975127>]
# Tonopah AZ ~ [CityMatch<Tonopah, Arizona, United States, wof:85919069>]
# Woodstock, VA ~ [CityMatch<Woodstock, Virginia, United States, wof:101728891>, CityMatch<Woodstock, Virginia, United States, wof:1126038991>]
# seattle, washington ~ [CityMatch<Seattle, Washington, United States, wof:101730401>]
# Fort Wayne, IN ~ [CityMatch<Fort Wayne, Indiana, United States, wof:85942149>]
# Columbiana, OH ~ [CityMatch<Columbiana, Ohio, United States, wof:85982919>]
# Waverly, TN ~ [CityMatch<Waverly, Tennessee, United States, wof:101722433>]
# Groveland, IL ~ [CityMatch<Groveland, Illinois, United States, wof:1125950663>]
# Sun Valley, Idaho ~ [CityMatch<Sun Valley, Idaho, United States, wof:85937941>]
# LA,CA ~ [CityMatch<Los Angeles, California, United States, wof:85923517>]
# Marion, TX ~ [CityMatch<Marion, Texas, United States, wof:101723461>, CityMatch<Marion, Texas, United States, wof:1125913583>]
# Carle Place, NY ~ [CityMatch<Carle Place, New York, United States, wof:85979163>]
# Deerfield Beach FL ~ [CityMatch<Deerfield Beach, Florida, United States, wof:85932401>]
