# %%
import csv
import us

import pandas as pd

# %%
us.states.lookup('AL').name
# Out:
# 'Alabama'

# %%
cols = (
    'geonameid',
    'name',
    'asciiname',
    'alternatenames',
    'latitude',
    'longitude',
    'feature_class',
    'feature_code',
    'country_code',
    'cc2',
    'admin1_code',
    'admin2_code',
    'admin3_code',
    'admin4_code',
    'population',
    'elevation',
    'dem',
    'timezone',
    'modification_date',
)

# %%
gn = pd.read_csv('../data/cities1000.txt', delimiter='\t', quoting=csv.QUOTE_NONE, names=cols)
# Out:
# /Users/dclure/Projects/litecoder/env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
class Litecoder:
    
    def __init__(self):
        self._cities = {}
        
    def index_geonames_city(row):
        self.index_city('geonames', row.geonameid, )

# %%
gn[gn.country_code=='US'][gn.population > 500000]
# Out:
# /Users/dclure/Projects/litecoder/env/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         geonameid               name          asciiname  \
# 131507    4140963   Washington, D.C.   Washington, D.C.
# 131841    4160021       Jacksonville       Jacksonville
# 132932    4259418       Indianapolis       Indianapolis
# 133762    4347778          Baltimore          Baltimore
# 134721    4460243          Charlotte          Charlotte
# 135306    4509177           Columbus           Columbus
# 135685    4544349      Oklahoma City      Oklahoma City
# 135845    4560349       Philadelphia       Philadelphia
# 136305    4641239            Memphis            Memphis
# 136323    4644585          Nashville          Nashville
# 136327    4645421  New South Memphis  New South Memphis
# 136459    4671654             Austin             Austin
# ...
